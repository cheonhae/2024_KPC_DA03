# %% [markdown]
# # 2장 파이썬 핵심 문법

# %% [markdown]
# ## 2.1 코랩 환경

# %%
print('안녕 파이썬!!')

# %%
x = 10
y = 20
print(x+y)

# %% [markdown]
# ## 2.2 변수

# %%
a=100
print(a)

# %%
a=100
a=200
print(a)

# %%
name='이순신'
addr='서울시'
print(name, addr)

# %%
age=20
age=age+5
print('5년 후 나이', age)

# %% [markdown]
# ## 2.3 연산자

# %%
x=10
y=20
print(x+y)

# %%
print(x-y)

# %%
print(x*y)

# %%
x=10
y=20
print(x/y)

# %%
print(x%y)

# %%
print(x**2)

# %%
print(x//y)

# %%
start='파이썬'
end=' 짱!'
start+end

# %%
word='파이썬 '
word*5

# %% [markdown]
# ## 2.4 표준 입·출력

# %%
name = input('이름 입력: ')
print(name)

# %%
x = int(input('숫자1 입력: '))
y = int(input('숫자2 입력: '))
print(x+y)

# %%
z = float(input('숫자 입력: '))
print(z)

# %%
print('파이썬')
print('짱')

# %%
print('파이썬', end=' ')
print('짱')

# %%
name = input('이름 입력: ')
print('입력한 이름은', name)

# %%
name = input('이름 입력: ')
print('입력한 이름은 %s' % name)

# %%
x = int(input('숫자1 입력: '))
y = int(input('숫자2 입력: '))
print('%d + %d = %d' % (x, y, x+y))

# %%
x = int(input('숫자1 입력: '))
y = int(input('숫자2 입력: '))
print('%d / %d = %f' % (x, y, x/y))

# %%
x = int(input('숫자1 입력: '))
y = int(input('숫자2 입력: '))
print('{0} * {1} = {2}'.format(x, y, x*y))

# %%
print('{1} {1} 작은 {0}'.format('별','반짝'))

# %%
x = int(input('숫자1 입력: '))
y = int(input('숫자2 입력: '))
print(f'{x} - {y} = {x-y}')
